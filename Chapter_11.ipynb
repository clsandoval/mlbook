# %%
# %config Completer.use_jedi = False

# %%
from tensorflow import keras as keras
import seaborn as sns
import numpy as np

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train_full = X_train_full / 255.0
X_test = X_test / 255.0
X_valid, X_train = X_train_full[:5000], X_train_full[5000:]
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

# %%
def split_dataset(X,y):
    sandal_indices = (y==5) | (y==6)
    X_train_A = X[~sandal_indices]
    X_train_B = X[sandal_indices]
    y_train_A = y[~sandal_indices]
    y_train_A[y_train_A>6] -= 2
    y_train_B = (y[sandal_indices]==6).astype(np.float32)
    return (X_train_A,X_train_B,y_train_A,y_train_B)
X_train_A,X_train_B,y_train_A,y_train_B = split_dataset(X_train,y_train)
X_valid_A,X_valid_B,y_valid_A,y_valid_B = split_dataset(X_valid,y_valid)
X_test_A,X_test_B,y_test_A,y_test_B = split_dataset(X_test,y_test)
X_train_B  =X_train_B[:200]
y_train_B  =y_train_B[:200]

# %%
model_A = keras.Sequential()
model_A.add(keras.layers.Flatten(input_shape=(28,28)))
for shape in (300,100,50,50,50):
    model_A.add(keras.layers.Dense(shape, activation='selu'))
model_A.add(keras.layers.Dense(8, activation='softmax'))
model_A.compile(loss="sparse_categorical_crossentropy", optimizer = keras.optimizers.SGD(lr=1e-3), metrics=['accuracy'])
model_A.summary()

history = model_A.fit(X_train_A, y_train_A, epochs=20,
                    validation_data=(X_valid_A, y_valid_A))
# Out:
# C:\Users\carlos\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 300)               235500
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 408
# =================================================================
# Total params: 276,158
# Trainable params: 276,158
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1375/1375 [==============================] - 9s 6ms/step - loss: 0.5543 - accuracy: 0.8175 - val_loss: 0.3830 - val_accuracy: 0.8682
# Epoch 2/20
# 1375/1375 [==============================] - 9s 6ms/step - loss: 0.3512 - accuracy: 0.8781 - val_loss: 0.3326 - val_accuracy: 0.8869
# Epoch 3/20
# 1375/1375 [==============================] - 7s 5ms/step - loss: 0.3176 - accuracy: 0.8894 - val_loss: 0.3086 - val_accuracy: 0.8949
# Epoch 4/20
# 1375/1375 [==============================] - 7s 5ms/step - loss: 0.2985 - accuracy: 0.8971 - val_loss: 0.2911 - val_accuracy: 0.9018
# Epoch 5/20
# 1375/1375 [==============================] - 7s 5ms/step - loss: 0.2848 - accuracy: 0.9020 - val_loss: 0.2815 - val_accuracy: 0.9051
# Epoch 6/20
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2739 - accuracy: 0.9064 - val_loss: 0.2762 - val_accuracy: 0.9083
# Epoch 7/20
# 1375/1375 [==============================] - 6s 5ms/step - loss: 0.2660 - accuracy: 0.9100 - val_loss: 0.2717 - val_accuracy: 0.9063
# Epoch 8/20
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.2587 - accuracy: 0.9114 - val_loss: 0.2616 - val_accuracy: 0.9106
# Epoch 9/20
# 1375/1375 [==============================] - 8s 6ms/step - loss: 0.2530 - accuracy: 0.9141 - val_loss: 0.2603 - val_accuracy: 0.9103
# Epoch 10/20
# 1375/1375 [==============================] - 7s 5ms/step - loss: 0.2474 - accuracy: 0.9158 - val_loss: 0.2556 - val_accuracy: 0.9158
# Epoch 11/20
# 1375/1375 [==============================] - 8s 6ms/step - loss: 0.2427 - accuracy: 0.9177 - val_loss: 0.2518 - val_accuracy: 0.9136
# Epoch 12/20
# 1375/1375 [==============================] - 8s 6ms/step - loss: 0.2388 - accuracy: 0.9186 - val_loss: 0.2505 - val_accuracy: 0.9160
# Epoch 13/20
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.2347 - accuracy: 0.9205 - val_loss: 0.2471 - val_accuracy: 0.9165
# Epoch 14/20
# 1375/1375 [==============================] - 7s 5ms/step - loss: 0.2312 - accuracy: 0.9211 - val_loss: 0.2445 - val_accuracy: 0.9180
# Epoch 15/20
# 1375/1375 [==============================] - 7s 5ms/step - loss: 0.2285 - accuracy: 0.9222 - val_loss: 0.2467 - val_accuracy: 0.9155
# Epoch 16/20
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2249 - accuracy: 0.9229 - val_loss: 0.2388 - val_accuracy: 0.9188
# Epoch 17/20
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2222 - accuracy: 0.9242 - val_loss: 0.2410 - val_accuracy: 0.9180
# Epoch 18/20
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2198 - accuracy: 0.9255 - val_loss: 0.2404 - val_accuracy: 0.9193
# Epoch 19/20
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2172 - accuracy: 0.9262 - val_loss: 0.2415 - val_accuracy: 0.9168
# Epoch 20/20
# 1375/1375 [==============================] - 5s 3ms/step - loss: 0.2150 - accuracy: 0.9271 - val_loss: 0.2361 - val_accuracy: 0.9188

# %% [markdown]
# ### Transfer Learning with Keras

# %%
model_A.save("my_model.h5")

# %%
model_B = keras.Sequential()
model_B.add(keras.layers.Flatten(input_shape=(28,28)))
for shape in (300,100,50,50,50):
    model_B.add(keras.layers.Dense(shape, activation='selu'))
model_B.add(keras.layers.Dense(1, activation='sigmoid'))
model_B.compile(loss="binary_crossentropy", optimizer = keras.optimizers.SGD(lr=1e-3), metrics=['accuracy'])
model_B.summary()

history = model_B.fit(X_train_B, y_train_B, epochs=20,
                    validation_data=(X_valid_B, y_valid_B))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 300)               235500
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_8 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_9 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_10 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 275,801
# Trainable params: 275,801
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 7/7 [==============================] - 1s 64ms/step - loss: 0.5727 - accuracy: 0.7400 - val_loss: 0.5271 - val_accuracy: 0.7718
# Epoch 2/20
# 7/7 [==============================] - 0s 18ms/step - loss: 0.4407 - accuracy: 0.8600 - val_loss: 0.4288 - val_accuracy: 0.8458
# Epoch 3/20
# 7/7 [==============================] - 0s 19ms/step - loss: 0.3556 - accuracy: 0.9050 - val_loss: 0.3602 - val_accuracy: 0.8945
# Epoch 4/20
# 7/7 [==============================] - 0s 18ms/step - loss: 0.2962 - accuracy: 0.9300 - val_loss: 0.3087 - val_accuracy: 0.9189
# Epoch 5/20
# 7/7 [==============================] - 0s 18ms/step - loss: 0.2516 - accuracy: 0.9550 - val_loss: 0.2673 - val_accuracy: 0.9462
# Epoch 6/20
# 7/7 [==============================] - 0s 20ms/step - loss: 0.2176 - accuracy: 0.9650 - val_loss: 0.2359 - val_accuracy: 0.9594
# Epoch 7/20
# 7/7 [==============================] - 0s 24ms/step - loss: 0.1898 - accuracy: 0.9750 - val_loss: 0.2117 - val_accuracy: 0.9655
# Epoch 8/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1688 - accuracy: 0.9800 - val_loss: 0.1913 - val_accuracy: 0.9686
# Epoch 9/20
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1512 - accuracy: 0.9900 - val_loss: 0.1756 - val_accuracy: 0.9736
# Epoch 10/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1376 - accuracy: 0.9900 - val_loss: 0.1634 - val_accuracy: 0.9757
# Epoch 11/20
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1268 - accuracy: 0.9900 - val_loss: 0.1514 - val_accuracy: 0.9787
# Epoch 12/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1164 - accuracy: 0.9900 - val_loss: 0.1413 - val_accuracy: 0.9787
# Epoch 13/20
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1076 - accuracy: 0.9900 - val_loss: 0.1327 - val_accuracy: 0.9807
# Epoch 14/20
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1002 - accuracy: 0.9900 - val_loss: 0.1253 - val_accuracy: 0.9807
# Epoch 15/20
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0936 - accuracy: 0.9900 - val_loss: 0.1186 - val_accuracy: 0.9817
# Epoch 16/20
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0879 - accuracy: 0.9900 - val_loss: 0.1129 - val_accuracy: 0.9828
# Epoch 17/20
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0829 - accuracy: 0.9900 - val_loss: 0.1077 - val_accuracy: 0.9858
# Epoch 18/20
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0782 - accuracy: 0.9900 - val_loss: 0.1029 - val_accuracy: 0.9858
# Epoch 19/20
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0740 - accuracy: 0.9900 - val_loss: 0.0985 - val_accuracy: 0.9858
# Epoch 20/20
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0700 - accuracy: 0.9950 - val_loss: 0.0946 - val_accuracy: 0.9868

# %%
model_A = keras.models.load_model("my_model.h5")
model_B_on_A = keras.models.Sequential(model_A.layers[:-1])
model_B_on_A.add(keras.layers.Dense(1,activation='sigmoid'))

# %%
for layer in model_B_on_A.layers[:-1]:
    layer.trainable = False
model_B_on_A.compile(loss="binary_crossentropy", optimizer="sgd",
metrics=["accuracy"])
history = model_B_on_A.fit(X_train_B, y_train_B, epochs=20,
                    validation_data=(X_valid_B, y_valid_B))
    
for layer in model_B_on_A.layers[:-1]:
    layer.trainable = True
model_B_on_A.compile(loss="binary_crossentropy", optimizer="sgd",
metrics=["accuracy"])
history = model_B_on_A.fit(X_train_B, y_train_B, epochs=20,
                    validation_data=(X_valid_B, y_valid_B))
# Out:
# Epoch 1/20
# 7/7 [==============================] - 1s 65ms/step - loss: 1.6468 - accuracy: 0.2450 - val_loss: 0.8181 - val_accuracy: 0.5051
# Epoch 2/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.6462 - accuracy: 0.6450 - val_loss: 0.3880 - val_accuracy: 0.8337
# Epoch 3/20
# 7/7 [==============================] - 0s 20ms/step - loss: 0.3271 - accuracy: 0.8600 - val_loss: 0.2413 - val_accuracy: 0.9331
# Epoch 4/20
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2092 - accuracy: 0.9550 - val_loss: 0.1740 - val_accuracy: 0.9635
# Epoch 5/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1518 - accuracy: 0.9700 - val_loss: 0.1405 - val_accuracy: 0.9736
# Epoch 6/20
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1215 - accuracy: 0.9750 - val_loss: 0.1178 - val_accuracy: 0.9797
# Epoch 7/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1007 - accuracy: 0.9950 - val_loss: 0.1036 - val_accuracy: 0.9838
# Epoch 8/20
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0874 - accuracy: 0.9950 - val_loss: 0.0923 - val_accuracy: 0.9878
# Epoch 9/20
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0769 - accuracy: 0.9950 - val_loss: 0.0845 - val_accuracy: 0.9888
# Epoch 10/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0693 - accuracy: 0.9950 - val_loss: 0.0778 - val_accuracy: 0.9888
# Epoch 11/20
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0629 - accuracy: 0.9950 - val_loss: 0.0723 - val_accuracy: 0.9899
# Epoch 12/20
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0577 - accuracy: 0.9950 - val_loss: 0.0683 - val_accuracy: 0.9899
# Epoch 13/20
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0538 - accuracy: 0.9950 - val_loss: 0.0648 - val_accuracy: 0.9899
# Epoch 14/20
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0504 - accuracy: 0.9950 - val_loss: 0.0615 - val_accuracy: 0.9909
# Epoch 15/20
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0472 - accuracy: 0.9950 - val_loss: 0.0589 - val_accuracy: 0.9909
# Epoch 16/20
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0447 - accuracy: 0.9950 - val_loss: 0.0566 - val_accuracy: 0.9909
# Epoch 17/20
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0424 - accuracy: 0.9950 - val_loss: 0.0545 - val_accuracy: 0.9909
# Epoch 18/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0404 - accuracy: 0.9950 - val_loss: 0.0528 - val_accuracy: 0.9909
# Epoch 19/20
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0387 - accuracy: 0.9950 - val_loss: 0.0511 - val_accuracy: 0.9909
# Epoch 20/20
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 0.0497 - val_accuracy: 0.9909
# Epoch 1/20
# 7/7 [==============================] - 1s 61ms/step - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9919
# Epoch 2/20
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0234 - accuracy: 0.9950 - val_loss: 0.0338 - val_accuracy: 0.9919
# Epoch 3/20
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0182 - accuracy: 0.9950 - val_loss: 0.0312 - val_accuracy: 0.9929
# Epoch 4/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 0.9919
# Epoch 5/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0282 - val_accuracy: 0.9919
# Epoch 6/20
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 0.9919
# Epoch 7/20
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0267 - val_accuracy: 0.9919
# Epoch 8/20
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 0.9909
# Epoch 9/20
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9919
# Epoch 10/20
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 0.9919
# Epoch 11/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9919
# Epoch 12/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9929
# Epoch 13/20
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9929
# Epoch 14/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9929
# Epoch 15/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9919
# Epoch 16/20
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9919
# Epoch 17/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9919
# Epoch 18/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9919
# Epoch 19/20
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9929
# Epoch 20/20
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 0.9929

# %%
model_B_on_A.evaluate(X_test_B,y_test_B)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0106 - accuracy: 0.9980
# [0.010568957775831223, 0.9980000257492065]

# %%
def exponential_decay(lr,s):
    def exponential_decay_fn(epoch):
        return 0.01 * 0.1**(epoch/20)
    return exponential_decay_fn
exponential_decay_fn = exponential_decay(0.01, 20)

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=[28,28]),
    keras.layers.Dense(300, activation='selu'),
    keras.layers.Dense(100, activation='selu'),
    keras.layers.Dense(10, activation='softmax')
])
lr_scheduler = keras.callbacks.LearningRateScheduler(exponential_decay_fn)
model.compile(loss="sparse_categorical_crossentropy",optimizer="nadam", metrics=["accuracy"])
history = model.fit(X_train,y_train,epochs = 25, validation_data = (X_valid,y_valid), callbacks = [lr_scheduler])

# %%
def piecewise_constant_fn(epoch):
    if epoch < 5:
        return 0.01
    elif epoch < 15:
        return 0.005
    else:
        return 0.001

# %%
lr_scheduler = keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)

# %%
layer = keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal", kernel_regularizer = keras.regularizers.l2(0.01))

# %%
from functools import partial

RegularizedDense = partial(
    keras.layers.Dense,
    activation="elu",
    kernel_initializer="he_normal",   
    kernel_regularizer = keras.regularizers.l2(0.01)
)

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=[28,28]),
    RegularizedDense(300),
    RegularizedDense(100),
    keras.layers.Dense(10, activation="softmax"),
])
model.compile(loss="sparse_categorical_crossentropy",optimizer="nadam", metrics=["accuracy"])
history = model.fit(X_train,y_train,epochs = 25, validation_data = (X_valid,y_valid), callbacks = [lr_scheduler])
# Out:
# Epoch 1/25
# 1719/1719 [==============================] - 10s 5ms/step - loss: 2.0990 - accuracy: 0.6027 - val_loss: 0.9647 - val_accuracy: 0.7318
# Epoch 2/25
# 1719/1719 [==============================] - 8s 5ms/step - loss: 2.6773 - accuracy: 0.6403 - val_loss: 3.3301 - val_accuracy: 0.6784
# Epoch 3/25
# 1719/1719 [==============================] - 8s 5ms/step - loss: 1.4727 - accuracy: 0.7021 - val_loss: 0.8950 - val_accuracy: 0.7706
# Epoch 4/25
# 1719/1719 [==============================] - 8s 5ms/step - loss: 1.5261 - accuracy: 0.7313 - val_loss: 0.8125 - val_accuracy: 0.7786
# Epoch 5/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 1.2302 - accuracy: 0.7407 - val_loss: 0.8390 - val_accuracy: 0.7570
# Epoch 6/25
# 1719/1719 [==============================] - 11s 7ms/step - loss: 1.2303 - accuracy: 0.7580 - val_loss: 1.5912 - val_accuracy: 0.7418
# Epoch 7/25
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.8936 - accuracy: 0.7793 - val_loss: 0.7655 - val_accuracy: 0.7924
# Epoch 8/25
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.7556 - accuracy: 0.7916 - val_loss: 0.7365 - val_accuracy: 0.8008
# Epoch 9/25
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.8173 - accuracy: 0.7913 - val_loss: 0.6702 - val_accuracy: 0.8230
# Epoch 10/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.7040 - accuracy: 0.8040 - val_loss: 0.7311 - val_accuracy: 0.7990
# Epoch 11/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.6861 - accuracy: 0.8072 - val_loss: 0.6636 - val_accuracy: 0.8156
# Epoch 12/25
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.6682 - accuracy: 0.8123 - val_loss: 0.6647 - val_accuracy: 0.8056
# Epoch 13/25
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.6527 - accuracy: 0.8138 - val_loss: 0.6371 - val_accuracy: 0.8180
# Epoch 14/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.6376 - accuracy: 0.8187 - val_loss: 0.6586 - val_accuracy: 0.8070
# Epoch 15/25
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.6236 - accuracy: 0.8202 - val_loss: 0.6246 - val_accuracy: 0.8288
# Epoch 16/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.6123 - accuracy: 0.8239 - val_loss: 0.5912 - val_accuracy: 0.8300
# Epoch 17/25
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.5998 - accuracy: 0.8259 - val_loss: 0.6249 - val_accuracy: 0.8194
# Epoch 18/25
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.5877 - accuracy: 0.8288 - val_loss: 0.5692 - val_accuracy: 0.8438
# Epoch 19/25
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.5843 - accuracy: 0.8297 - val_loss: 0.5801 - val_accuracy: 0.8318
# Epoch 20/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.5751 - accuracy: 0.8317 - val_loss: 0.5679 - val_accuracy: 0.8354
# Epoch 21/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.5670 - accuracy: 0.8332 - val_loss: 0.5687 - val_accuracy: 0.8416
# Epoch 22/25
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.5589 - accuracy: 0.8371 - val_loss: 0.5577 - val_accuracy: 0.8370
# Epoch 23/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.5525 - accuracy: 0.8368 - val_loss: 0.6100 - val_accuracy: 0.8136
# Epoch 24/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.5483 - accuracy: 0.8391 - val_loss: 0.5976 - val_accuracy: 0.8186
# Epoch 25/25
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.5432 - accuracy: 0.8397 - val_loss: 0.5281 - val_accuracy: 0.8490

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape = [28,28]),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(300, activation='elu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(100, activation='elu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax'),
])
model.compile(optimizer= "nadam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(X_train,y_train, epochs=25, validation_data=(X_valid,y_valid),callbacks=[lr_scheduler])
# Out:
# Epoch 1/25
# 1719/1719 [==============================] - 16s 7ms/step - loss: 0.8158 - accuracy: 0.7217 - val_loss: 0.5012 - val_accuracy: 0.8260
# Epoch 2/25
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.6632 - accuracy: 0.7717 - val_loss: 0.5200 - val_accuracy: 0.8110
# Epoch 3/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.6139 - accuracy: 0.7869 - val_loss: 0.4815 - val_accuracy: 0.8370
# Epoch 4/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.5783 - accuracy: 0.7973 - val_loss: 0.5364 - val_accuracy: 0.8230
# Epoch 5/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.5509 - accuracy: 0.8048 - val_loss: 0.3933 - val_accuracy: 0.8618
# Epoch 6/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.5424 - accuracy: 0.8109 - val_loss: 0.5203 - val_accuracy: 0.8472
# Epoch 7/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.5117 - accuracy: 0.8195 - val_loss: 0.4209 - val_accuracy: 0.8582
# Epoch 8/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4872 - accuracy: 0.8265 - val_loss: 0.3795 - val_accuracy: 0.8684
# Epoch 9/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4763 - accuracy: 0.8311 - val_loss: 0.3805 - val_accuracy: 0.8552
# Epoch 10/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4534 - accuracy: 0.8378 - val_loss: 0.4037 - val_accuracy: 0.8534
# Epoch 11/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4379 - accuracy: 0.8422 - val_loss: 0.3854 - val_accuracy: 0.8668
# Epoch 12/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4266 - accuracy: 0.8467 - val_loss: 0.3493 - val_accuracy: 0.8714
# Epoch 13/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4164 - accuracy: 0.8508 - val_loss: 0.3530 - val_accuracy: 0.8764
# Epoch 14/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4078 - accuracy: 0.8533 - val_loss: 0.3712 - val_accuracy: 0.8748
# Epoch 15/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3926 - accuracy: 0.8577 - val_loss: 0.3467 - val_accuracy: 0.8826
# Epoch 16/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3868 - accuracy: 0.8586 - val_loss: 0.3366 - val_accuracy: 0.8742
# Epoch 17/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3775 - accuracy: 0.8624 - val_loss: 0.3230 - val_accuracy: 0.8918
# Epoch 18/25
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3707 - accuracy: 0.8645 - val_loss: 0.3224 - val_accuracy: 0.8898
# Epoch 19/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3629 - accuracy: 0.8666 - val_loss: 0.3423 - val_accuracy: 0.8838
# Epoch 20/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3596 - accuracy: 0.8693 - val_loss: 0.3188 - val_accuracy: 0.8892
# Epoch 21/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3504 - accuracy: 0.8724 - val_loss: 0.3165 - val_accuracy: 0.8858
# Epoch 22/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3454 - accuracy: 0.8742 - val_loss: 0.3203 - val_accuracy: 0.8906
# Epoch 23/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3427 - accuracy: 0.8731 - val_loss: 0.3232 - val_accuracy: 0.8840
# Epoch 24/25
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3404 - accuracy: 0.8745 - val_loss: 0.3117 - val_accuracy: 0.8908
# Epoch 25/25
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3337 - accuracy: 0.8767 - val_loss: 0.3170 - val_accuracy: 0.8880

# %% [markdown]
# ### Exercises

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.cifar10.load_data()
X_train_full = X_train_full / 255.0
X_test = X_test / 255.0
X_valid, X_train = X_train_full[:5000], X_train_full[5000:]
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape=[32,32,3]))
for i in range(20):
    model.add(keras.layers.Dense(100,kernel_initializer='he_normal'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Activation("elu"))
model.add(keras.layers.Dense(10,activation="softmax"))
model.compile(optimizer="nadam", loss= "sparse_categorical_crossentropy", metrics =["accuracy"])
history = model.fit(X_train,y_train,epochs = 20, validation_data = (X_valid,y_valid), callbacks = [keras.callbacks.EarlyStopping(patience=10)])
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 53s 20ms/step - loss: 1.8395 - accuracy: 0.3382 - val_loss: 1.9747 - val_accuracy: 0.3132
# Epoch 2/20
# 1407/1407 [==============================] - 32s 22ms/step - loss: 1.6820 - accuracy: 0.4006 - val_loss: 1.7237 - val_accuracy: 0.3786
# Epoch 3/20
# 1407/1407 [==============================] - 45s 32ms/step - loss: 1.6173 - accuracy: 0.4218 - val_loss: 1.6808 - val_accuracy: 0.3876
# Epoch 4/20
# 1407/1407 [==============================] - 45s 32ms/step - loss: 1.5700 - accuracy: 0.4401 - val_loss: 1.8701 - val_accuracy: 0.3468
# Epoch 5/20
# 1407/1407 [==============================] - 45s 32ms/step - loss: 1.5210 - accuracy: 0.4619 - val_loss: 1.6853 - val_accuracy: 0.4072
# Epoch 6/20
# 1407/1407 [==============================] - 44s 32ms/step - loss: 1.4859 - accuracy: 0.4724 - val_loss: 1.7098 - val_accuracy: 0.3932
# Epoch 7/20
# 1407/1407 [==============================] - 44s 32ms/step - loss: 1.4524 - accuracy: 0.4858 - val_loss: 1.4406 - val_accuracy: 0.4908
# Epoch 8/20
# 1407/1407 [==============================] - 44s 31ms/step - loss: 1.4247 - accuracy: 0.4945 - val_loss: 1.6601 - val_accuracy: 0.4248
# Epoch 9/20
# 1407/1407 [==============================] - 46s 32ms/step - loss: 1.3951 - accuracy: 0.5085 - val_loss: 1.4720 - val_accuracy: 0.4780
# Epoch 10/20
# 1407/1407 [==============================] - 43s 31ms/step - loss: 1.3677 - accuracy: 0.5174 - val_loss: 1.5715 - val_accuracy: 0.4526
# Epoch 11/20
# 1407/1407 [==============================] - 27s 19ms/step - loss: 1.3390 - accuracy: 0.5252 - val_loss: 1.4403 - val_accuracy: 0.4990
# Epoch 12/20
# 1407/1407 [==============================] - 38s 27ms/step - loss: 1.3251 - accuracy: 0.5334 - val_loss: 1.5396 - val_accuracy: 0.4596
# Epoch 13/20
# 1407/1407 [==============================] - 46s 32ms/step - loss: 1.3024 - accuracy: 0.5374 - val_loss: 1.5321 - val_accuracy: 0.4642
# Epoch 14/20
# 1407/1407 [==============================] - 44s 31ms/step - loss: 1.2826 - accuracy: 0.5438 - val_loss: 1.4746 - val_accuracy: 0.4916
# Epoch 15/20
# 1407/1407 [==============================] - 45s 32ms/step - loss: 1.2627 - accuracy: 0.5556 - val_loss: 1.4527 - val_accuracy: 0.4872
# Epoch 16/20
# 1407/1407 [==============================] - 45s 32ms/step - loss: 1.2429 - accuracy: 0.5630 - val_loss: 1.4389 - val_accuracy: 0.4942
# Epoch 17/20
# 1407/1407 [==============================] - 35s 25ms/step - loss: 1.2278 - accuracy: 0.5682 - val_loss: 1.4122 - val_accuracy: 0.5040
# Epoch 18/20
# 1407/1407 [==============================] - 39s 28ms/step - loss: 1.2095 - accuracy: 0.5749 - val_loss: 1.4006 - val_accuracy: 0.5094
# Epoch 19/20
# 1407/1407 [==============================] - 42s 30ms/step - loss: 1.1966 - accuracy: 0.5771 - val_loss: 1.4900 - val_accuracy: 0.4924
# Epoch 20/20
# 1407/1407 [==============================] - 37s 26ms/step - loss: 1.1795 - accuracy: 0.5827 - val_loss: 1.5186 - val_accuracy: 0.4852
